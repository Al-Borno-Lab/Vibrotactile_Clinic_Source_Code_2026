# %%
import matplotlib.pyplot as plt
from MedtronicPerceptAnalysisTool import PatientDatasetRegistry
from MedtronicPerceptAnalysisTool.plotter.all_patients.all_patients import plot_freqRange_powerMean_of_treatment1_2_normalized_intertreatment_baseline
from MedtronicPerceptAnalysisTool.utility.constants import FrequencyRange
import pandas as pd
import numpy as np
from MedtronicPerceptAnalysisTool.plotter.all_patients.all_patients import plot_all_hemi_type_inter
import numpy as np
from scipy import stats
from scipy.stats import ttest_ind, wilcoxon, ranksums, mannwhitneyu, ttest_rel
from matplotlib import cm as cmap
import dateutil 
import copy
viridis = cmap.get_cmap('gist_ncar', 15)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

df_all = PatientDatasetRegistry().all_dataframe_lfp()

freq_range = FrequencyRange.Beta.value
nopeaks = [2,3,5,8,9]
# Out:
# C:\Users\Jesse\AppData\Local\Temp\ipykernel_47248\3040565140.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis = cmap.get_cmap('gist_ncar', 15)

# %%
def round1000(value):
    return np.round(value*1000)/1000

def gatherPSD(data, p1 = 12, p2 = 30):
    r = data["PSD_(1, 100)"]
    gather = []
    for i,d in enumerate(r):
        w1 = int(np.argwhere(d.frequency==p1))
        w2 = int(np.argwhere(d.frequency==p2))
        gather.append(d.PSD[w1:w2])
    g = np.array(gather)
    return g

def custombox(data,position, scatter = False, sds = True, w = [.5], scattersize = 2, color = 'k',alpha=.5):
    data = np.array(data).flatten()
    plt.boxplot(np.array(data), positions= [position], widths = w)
    if scatter:
        r = np.random.randn(data.shape[0])/30
        plt.scatter(data*0+position+r,data,scattersize,color,alpha=alpha)
    plt.plot([position-w[0]/2, position+w[0]/2],[np.mean(data), np.mean(data)],'g')
    if sds:
        plt.plot([position-w[0]/2, position+w[0]/2],[np.mean(data)-np.std(data)/np.sqrt(data.shape[0]), np.mean(data)-np.std(data)/np.sqrt(data.shape[0])],'g', alpha=.5)
        plt.plot([position-w[0]/2, position+w[0]/2],[np.mean(data)+np.std(data)/np.sqrt(data.shape[0]), np.mean(data)+np.std(data)/np.sqrt(data.shape[0])],'g', alpha=.5)

def customUnravel(data):
    meow = []
    for i in data:
        for j in i:
            meow.append(j)
    return np.array(meow).flatten()

def exportFigure(name):
    plt.savefig(name+".svg")
    plt.savefig(name+".png")

def printTtest(data1,data2,name1,name2):
    a = stats.ttest_ind(data1.flatten(),data2.flatten())
    print(name1," vs. ",name2)
    
    if a.pvalue <= 0.05:
        print("Significant, p: ", a.pvalue)
    else:
        print("Non-significant, p: ", a.pvalue)
    
    print(name1, " mean is: ", round1000(np.mean(data1)), " SEM is: ", round1000(np.std(data1)/np.sqrt(len(data1))), " Median is: ", round1000(np.median(data1)))
    print(name2, " mean is: ", round1000(np.mean(data2)), " SEM is: ", round1000(np.std(data2)/np.sqrt(len(data2))), " Median is: ", round1000(np.median(data2)))
    print("")
    return a.pvalue

def statout(base,allon,rvs):
    print("DBS-off mean: "  ,     round1000(np.mean(base)),\
          "\nDBS-off median: ",   round1000(np.median(base)),\
          "\nDBS-off st. dev.: ", round1000(np.std(base)),\
          "\nDBS-off SEM: ",      round1000(np.std(base)/np.sqrt(len(base))),\
          "\n")
    print("All-on mean: "  ,     round1000(np.mean(allon)),\
          "\nAll-on median: ",   round1000(np.median(allon)),\
          "\nAll-on st. dev.: ", round1000(np.std(allon)),\
          "\nAll-on SEM: ",      round1000(np.std(allon)/np.sqrt(len(allon))),\
          "\n")
    print("RVS mean: "  ,     round1000(np.mean(rvs)),\
          "\nRVS median: ",   round1000(np.median(rvs)),\
          "\nRVS st. dev.: ", round1000(np.std(rvs)),\
          "\nRVS SEM: ",      round1000(np.std(rvs)/np.sqrt(len(rvs))),\
          "\n")
    return 0

def gen_allSession_Data(data, p1 = 13, p2 = 30, baseCut = -3, testCut = -6, toMax = False):
    base = data.loc[(data["TreatmentBranch"] == "dbs_off")]
    allon = data.loc[(data["TreatmentBranch"] == "all_on")]
    rvs = data.loc[(data["TreatmentBranch"] == "rvs")]
    
    mg = np.ndarray(len(np.unique(base["PatientNumber"]))*2)
    maxmult = np.ndarray(len(np.unique(base["PatientNumber"]))*2)
    baseValues = []
    baseMeans =  []
    xi = 0
    for x,p in enumerate(base.groupby("PatientNumber")):
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            
            mg[xi] = np.mean(gather[-baseCut:])
            #if toMax:
            #    mg[xi] = np.mean(np.max(gather[-baseCut:],axis=1))
            gather = gather/mg[xi]
            if toMax:
                maxmult[xi] = np.mean(np.max(gather[-baseCut:,:],axis=0))
                maxmult[xi] = 1
                gather = (gather-maxmult[xi])/maxmult[xi]*100
            else:
                gather = (gather-1)/1*100
            if toMax:
                baseValues.append(np.max(gather[baseCut:,:],axis=1))
                baseMeans.append( np.mean(np.max(gather[baseCut:,:],axis=1)) )
            else:
                baseValues.append(np.mean(gather[baseCut:,:],axis=1))
                baseMeans.append( np.mean(np.mean(gather[baseCut:,:],axis=1)) )
            xi += 1
    baseValues = customUnravel(baseValues)
    baseMeans =  np.array(baseMeans).flatten()
    
    allValues = []
    allMeans = []
    xi = 0
    for x,p in enumerate(allon.groupby("PatientNumber")):
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            gather = gather/mg[xi]
            
            if toMax:
                gather = (gather-maxmult[xi])/maxmult[xi]*100
            else:
                gather = (gather-1)/1*100
                
            if toMax:
                allValues.append(np.max(gather[testCut:,:],axis=1))
                allMeans.append( np.mean(np.max(gather[testCut:,:],axis=1)) )
            else:
                allValues.append(np.mean(gather[testCut:,:],axis=1))
                allMeans.append( np.mean(np.mean(gather[testCut:,:],axis=1)) )
            
            xi += 1
    allValues = customUnravel(allValues)
    allMeans =  np.array(allMeans).flatten()
    
    rvsValues = []
    rvsMeans = []
    xi = 0
    for x,p in enumerate(rvs.groupby("PatientNumber")):
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            gather = gather/mg[xi]
            
            if toMax:
                gather = (gather-maxmult[xi])/maxmult[xi]*100
            else:
                gather = (gather-1)/1*100
                
            if toMax:
                rvsValues.append(np.max(gather[testCut:,:],axis=1))
                rvsMeans.append( np.mean(np.max(gather[testCut:,:],axis=1)) )
            else:
                rvsValues.append(np.mean(gather[testCut:,:],axis=1))
                rvsMeans.append( np.mean(np.mean(gather[testCut:,:],axis=1)) )
            xi += 1
    rvsValues = customUnravel(rvsValues)
    rvsMeans =  np.array(rvsMeans).flatten()
    
    return baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans

def gen_allSession_Data_maxInd(data, p1 = 13, p2 = 30, baseCut = -3, testCut = -6, toMax = False):
    base = data.loc[(data["TreatmentBranch"] == "dbs_off")]
    allon = data.loc[(data["TreatmentBranch"] == "all_on")]
    rvs = data.loc[(data["TreatmentBranch"] == "rvs")]
    
    mg = np.ndarray(len(np.unique(base["PatientNumber"]))*2)
    maxind = np.ndarray(len(np.unique(base["PatientNumber"]))*2,dtype="int16")
    
    baseValues = []
    baseMeans =  []
    xi = 0
    for x,p in enumerate(base.groupby("PatientNumber")):
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            mg[xi] = np.mean(gather[-baseCut:])
            #maxind[xi] = np.argmax(np.mean(gather,axis=0))
            maxind[xi] = np.argmax(gather[0,:])

            gather = gather/mg[xi]
            gather = (gather-1)/1*100
            baseValues.append(gather[baseCut:,maxind[xi]])
            baseMeans.append( np.mean(gather[baseCut:,maxind[xi]]) )
            xi += 1
    baseValues = customUnravel(baseValues)
    baseMeans =  np.array(baseMeans).flatten()
    
    allValues = []
    allMeans = []
    xi = 0
    for x,p in enumerate(allon.groupby("PatientNumber")):
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            gather = gather/mg[xi]
            gather = (gather-1)/1*100
            allValues.append(gather[testCut:,maxind[xi]])
            allMeans.append( np.mean(gather[testCut:,maxind[xi]]) )
            
            xi += 1
    allValues = customUnravel(allValues)
    allMeans =  np.array(allMeans).flatten()
    
    rvsValues = []
    rvsMeans = []
    xi = 0
    for x,p in enumerate(rvs.groupby("PatientNumber")):
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            gather = gather/mg[xi]
            gather = (gather-1)/1*100
            rvsValues.append(gather[testCut:,maxind[xi]])
            rvsMeans.append( np.mean(gather[testCut:,maxind[xi]]) )
            xi += 1
    rvsValues = customUnravel(rvsValues)
    rvsMeans =  np.array(rvsMeans).flatten()
    
    return baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans

def gen_peaked_Data(data, p1 = 13, p2 = 30, baseCut = -3, testCut = -6, toMax = False, peaks = True):
    base = data.loc[(data["TreatmentBranch"] == "dbs_off")]
    allon = data.loc[(data["TreatmentBranch"] == "all_on")]
    rvs = data.loc[(data["TreatmentBranch"] == "rvs")]
    
    mg = np.ndarray(len(np.unique(base["PatientNumber"]))*2)
    
    baseValues = []
    baseMeans =  []
    xi = 0
    for x,p in enumerate(base.groupby("PatientNumber")):
        if peaks:
            if p[1]["PatientNumber"].iloc[0] in nopeaks:
                continue
        if not peaks:
            if p[1]["PatientNumber"].iloc[0] not in nopeaks:
                continue
        print(p[1]["PatientNumber"].iloc[0])
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            if peak:
                mg[xi] = np.max(gather[-baseCut:])
            else:
                mg[xi] = np.mean(gather[-baseCut:])
            gather = gather/mg[xi]
            gather = (gather-1)/1*100
            baseValues.append(np.mean(gather[baseCut:,:],axis=1))
            baseMeans.append( np.mean(np.mean(gather[baseCut:,:],axis=1)) )
            xi += 1
    baseValues = customUnravel(baseValues)
    baseMeans =  np.array(baseMeans).flatten()
    
    allValues = []
    allMeans = []
    xi = 0
    for x,p in enumerate(allon.groupby("PatientNumber")):
        if peaks:
            if p[1]["PatientNumber"].iloc[0] in nopeaks:
                continue
        if not peaks:
            if p[1]["PatientNumber"].iloc[0] not in nopeaks:
                continue
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            gather = gather/mg[xi]
            gather = (gather-1)/1*100
            allValues.append(np.mean(gather[testCut:,:],axis=1))
            allMeans.append( np.mean(np.mean(gather[testCut:,:],axis=1)) )
            xi += 1
    allValues = customUnravel(allValues)
    allMeans =  np.array(allMeans).flatten()
    
    rvsValues = []
    rvsMeans = []
    xi = 0
    for x,p in enumerate(rvs.groupby("PatientNumber")):
        if peaks:
            if p[1]["PatientNumber"].iloc[0] in nopeaks:
                continue
        if not peaks:
            if p[1]["PatientNumber"].iloc[0] not in nopeaks:
                continue
        for j,c in enumerate(p[1].groupby("IpsiContra")):
            gather = gatherPSD(c[1], p1, p2)
            gather = gather/mg[xi]
            gather = (gather-1)/1*100
            rvsValues.append(np.mean(gather[testCut:,:],axis=1))
            rvsMeans.append( np.mean(np.mean(gather[testCut:,:],axis=1)) )
            xi += 1
    rvsValues = customUnravel(rvsValues)
    rvsMeans =  np.array(rvsMeans).flatten()
    
    return baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans

# %%
data2 = copy.deepcopy(df_all)
data = data2[(data2["TreatmentOrder"] == "dbs_off,rvs,all_on")]
print(np.unique(data["PatientNumber"]))
data = data2[(data2["TreatmentOrder"] == "dbs_off,all_on,rvs")]
print(np.unique(data["PatientNumber"]))
# Out:
# [ 2  3  4  8 10 12]
# [ 1  5  7  9 11 13]

# %% [markdown]
# # change in mean distributions,
# 13 to 30
# 12, 20
# 20, 30

# %%
p1 = 13
p2 = 30

data = copy.deepcopy(df_all)

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')

plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
exportFigure("Mean_13_30_Fig2A")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)

p1 = 13
p2 = 20

data = copy.deepcopy(df_all)

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')

plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
plt.ylim([-75,100])
exportFigure("Mean_13_20_Fig2B")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)

p1 = 20
p2 = 30

data = copy.deepcopy(df_all)

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')

plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
plt.ylim([-75,100])
exportFigure("Mean_20_30_Fig2C")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)
# Out:
# DBS-off  vs.  All-on
# Non-significant, p:  0.12778568786635522
# DBS-off  mean is:  0.99  SEM is:  1.505  Median is:  1.568
# All-on  mean is:  -5.111  SEM is:  2.765  Median is:  -12.062
#
# DBS-off  vs.  RVS
# Significant, p:  0.011598897761998456
# DBS-off  mean is:  0.99  SEM is:  1.505  Median is:  1.568
# RVS  mean is:  -8.178  SEM is:  2.413  Median is:  -5.328
#
# All-on  vs.  RVS
# Non-significant, p:  0.40486779472948387
# All-on  mean is:  -5.111  SEM is:  2.765  Median is:  -12.062
# RVS  mean is:  -8.178  SEM is:  2.413  Median is:  -5.328
#
# DBS-off mean:  0.99
# DBS-off median:  1.568
# DBS-off st. dev.:  11.66
# DBS-off SEM:  1.505
#
# All-on mean:  -5.111
# All-on median:  -12.062
# All-on st. dev.:  29.52
# All-on SEM:  2.765
#
# RVS mean:  -8.178
# RVS median:  -5.328
# RVS st. dev.:  26.434
# RVS SEM:  2.413
# DBS-off  vs.  All-on
# Non-significant, p:  0.9676705991291282
# DBS-off  mean is:  0.708  SEM is:  1.9  Median is:  -0.201
# All-on  mean is:  0.45  SEM is:  4.471  Median is:  -5.298
#
# DBS-off  vs.  RVS
# Non-significant, p:  0.21594907346598927
# DBS-off  mean is:  0.708  SEM is:  1.9  Median is:  -0.201
# RVS  mean is:  -4.476  SEM is:  2.777  Median is:  -0.871
#
# All-on  vs.  RVS
# Non-significant, p:  0.34716930351979447
# All-on  mean is:  0.45  SEM is:  4.471  Median is:  -5.298
# RVS  mean is:  -4.476  SEM is:  2.777  Median is:  -0.871
#
# DBS-off mean:  0.708
# DBS-off median:  -0.201
# DBS-off st. dev.:  14.718
# DBS-off SEM:  1.9
#
# All-on mean:  0.45
# All-on median:  -5.298
# All-on st. dev.:  47.74
# All-on SEM:  4.471
#
# RVS mean:  -4.476
# RVS median:  -0.871
# RVS st. dev.:  30.425
# RVS SEM:  2.777
# DBS-off  vs.  All-on
# Non-significant, p:  0.061503743757124696
# DBS-off  mean is:  1.311  SEM is:  1.633  Median is:  1.224
# All-on  mean is:  -7.868  SEM is:  3.411  Median is:  -15.748
#
# DBS-off  vs.  RVS
# Significant, p:  0.0014116708087837458
# DBS-off  mean is:  1.311  SEM is:  1.633  Median is:  1.224
# RVS  mean is:  -10.67  SEM is:  2.466  Median is:  -11.273
#
# All-on  vs.  RVS
# Non-significant, p:  0.5049358293223666
# All-on  mean is:  -7.868  SEM is:  3.411  Median is:  -15.748
# RVS  mean is:  -10.67  SEM is:  2.466  Median is:  -11.273
#
# DBS-off mean:  1.311
# DBS-off median:  1.224
# DBS-off st. dev.:  12.651
# DBS-off SEM:  1.633
#
# All-on mean:  -7.868
# All-on median:  -15.748
# All-on st. dev.:  36.421
# All-on SEM:  3.411
#
# RVS mean:  -10.67
# RVS median:  -11.273
# RVS st. dev.:  27.014
# RVS SEM:  2.466
# 0

# %%
p1 = 13
p2 = 30

data = copy.deepcopy(df_all)

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')
plt.ylim([-50,350])
plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
exportFigure("Max_13_30_Fig2D")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)

p1 = 13
p2 = 20

data = copy.deepcopy(df_all)

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')
plt.ylim([-50,350])
plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
exportFigure("Max_13_20_Fig2E")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)

p1 = 20
p2 = 30

data = copy.deepcopy(df_all)

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')

plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
plt.ylim([-50,350])
exportFigure("Max_20_30_Fig2F")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)
# Out:
# DBS-off  vs.  All-on
# Non-significant, p:  0.4109871091294909
# DBS-off  mean is:  116.841  SEM is:  9.654  Median is:  98.25
# All-on  mean is:  103.384  SEM is:  10.625  Median is:  76.474
#
# DBS-off  vs.  RVS
# Significant, p:  0.002363516101763221
# DBS-off  mean is:  116.841  SEM is:  9.654  Median is:  98.25
# RVS  mean is:  83.426  SEM is:  5.893  Median is:  78.934
#
# All-on  vs.  RVS
# Non-significant, p:  0.09883730151455797
# All-on  mean is:  103.384  SEM is:  10.625  Median is:  76.474
# RVS  mean is:  83.426  SEM is:  5.893  Median is:  78.934
#
# DBS-off mean:  116.841
# DBS-off median:  98.25
# DBS-off st. dev.:  74.777
# DBS-off SEM:  9.654
#
# All-on mean:  103.384
# All-on median:  76.474
# All-on st. dev.:  113.447
# All-on SEM:  10.625
#
# RVS mean:  83.426
# RVS median:  78.934
# RVS st. dev.:  64.552
# RVS SEM:  5.893
# DBS-off  vs.  All-on
# Non-significant, p:  0.8999685752504551
# DBS-off  mean is:  61.502  SEM is:  8.886  Median is:  38.453
# All-on  mean is:  59.362  SEM is:  11.337  Median is:  35.701
#
# DBS-off  vs.  RVS
# Significant, p:  0.010016900641337334
# DBS-off  mean is:  61.502  SEM is:  8.886  Median is:  38.453
# RVS  mean is:  39.425  SEM is:  3.978  Median is:  40.801
#
# All-on  vs.  RVS
# Non-significant, p:  0.09329633046679481
# All-on  mean is:  59.362  SEM is:  11.337  Median is:  35.701
# RVS  mean is:  39.425  SEM is:  3.978  Median is:  40.801
#
# DBS-off mean:  61.502
# DBS-off median:  38.453
# DBS-off st. dev.:  68.828
# DBS-off SEM:  8.886
#
# All-on mean:  59.362
# All-on median:  35.701
# All-on st. dev.:  121.05
# All-on SEM:  11.337
#
# RVS mean:  39.425
# RVS median:  40.801
# RVS st. dev.:  43.579
# RVS SEM:  3.978
# DBS-off  vs.  All-on
# Significant, p:  0.0137007474658583
# DBS-off  mean is:  83.51  SEM is:  6.377  Median is:  78.779
# All-on  mean is:  59.294  SEM is:  6.158  Median is:  46.886
#
# DBS-off  vs.  RVS
# Significant, p:  0.0019162610717530885
# DBS-off  mean is:  83.51  SEM is:  6.377  Median is:  78.779
# RVS  mean is:  53.94  SEM is:  5.78  Median is:  44.186
#
# All-on  vs.  RVS
# Non-significant, p:  0.528100455689265
# All-on  mean is:  59.294  SEM is:  6.158  Median is:  46.886
# RVS  mean is:  53.94  SEM is:  5.78  Median is:  44.186
#
# DBS-off mean:  83.51
# DBS-off median:  78.779
# DBS-off st. dev.:  49.399
# DBS-off SEM:  6.377
#
# All-on mean:  59.294
# All-on median:  46.886
# All-on st. dev.:  65.747
# All-on SEM:  6.158
#
# RVS mean:  53.94
# RVS median:  44.186
# RVS st. dev.:  63.317
# RVS SEM:  5.78
# 0

# %%
p1 = 13
p2 = 30

data = copy.deepcopy(df_all)
data = data[(data["IpsiContra"] == "contra")]

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')

plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
plt.ylim([-75,100])
exportFigure("Mean_13_30_Contra_Fig2G")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)

p1 = 13
p2 = 30

data = copy.deepcopy(df_all)
data = data[(data["IpsiContra"] == "contra")]

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')

plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
exportFigure("Max_13_30_Contra_Fig2G_extra")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)
# Out:
# DBS-off  vs.  All-on
# Non-significant, p:  0.2561557843671655
# DBS-off  mean is:  1.475  SEM is:  1.966  Median is:  1.992
# All-on  mean is:  -4.434  SEM is:  3.557  Median is:  -12.964
#
# DBS-off  vs.  RVS
# Significant, p:  0.015279987714929347
# DBS-off  mean is:  1.475  SEM is:  1.966  Median is:  1.992
# RVS  mean is:  -8.991  SEM is:  2.806  Median is:  -7.997
#
# All-on  vs.  RVS
# Non-significant, p:  0.31758185493826757
# All-on  mean is:  -4.434  SEM is:  3.557  Median is:  -12.964
# RVS  mean is:  -8.991  SEM is:  2.806  Median is:  -7.997
#
# DBS-off mean:  1.475
# DBS-off median:  1.992
# DBS-off st. dev.:  11.793
# DBS-off SEM:  1.966
#
# All-on mean:  -4.434
# All-on median:  -12.964
# All-on st. dev.:  29.549
# All-on SEM:  3.557
#
# RVS mean:  -8.991
# RVS median:  -7.997
# RVS st. dev.:  23.813
# RVS SEM:  2.806
# DBS-off  vs.  All-on
# Non-significant, p:  0.7657207043350578
# DBS-off  mean is:  120.411  SEM is:  13.325  Median is:  100.312
# All-on  mean is:  113.944  SEM is:  13.838  Median is:  80.866
#
# DBS-off  vs.  RVS
# Significant, p:  0.019817792638800298
# DBS-off  mean is:  120.411  SEM is:  13.325  Median is:  100.312
# RVS  mean is:  87.306  SEM is:  7.192  Median is:  87.378
#
# All-on  vs.  RVS
# Non-significant, p:  0.0883498469938052
# All-on  mean is:  113.944  SEM is:  13.838  Median is:  80.866
# RVS  mean is:  87.306  SEM is:  7.192  Median is:  87.378
#
# DBS-off mean:  120.411
# DBS-off median:  100.312
# DBS-off st. dev.:  79.947
# DBS-off SEM:  13.325
#
# All-on mean:  113.944
# All-on median:  80.866
# All-on st. dev.:  114.949
# All-on SEM:  13.838
#
# RVS mean:  87.306
# RVS median:  87.378
# RVS st. dev.:  61.023
# RVS SEM:  7.192
# 0

# %%
p1 = 13
p2 = 30

data = copy.deepcopy(df_all)
data = data[(data["IpsiContra"] == "ipsi")]

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')
plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
plt.ylim([-75,100])
exportFigure("Mean_13_30_ipsi_Fig2H")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)

p1 = 13
p2 = 30

data = copy.deepcopy(df_all)
data = data[(data["IpsiContra"] == "ipsi")]

baseValues, baseMeans, allValues, allMeans, rvsValues, rvsMeans = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( allValues,2, scatter = True, sds = True, w = [.5], color = 'b')

custombox( rvsValues,3, scatter = True, sds = True, w = [.5], color = 'r')
plt.xticks([1,2,3],labels = ["DBS-off","All-on","RVS"])
exportFigure("Max_13_30_ipsi_Fig2H_extra")
plt.show()

printTtest(baseValues,allValues,"DBS-off","All-on")
printTtest(baseValues,rvsValues,"DBS-off","RVS")
printTtest(allValues,rvsValues,"All-on","RVS")
statout(baseValues,allValues,rvsValues)
# Out:
# DBS-off  vs.  All-on
# Non-significant, p:  0.3153345740669677
# DBS-off  mean is:  0.264  SEM is:  2.331  Median is:  -0.458
# All-on  mean is:  -6.15  SEM is:  4.389  Median is:  -9.678
#
# DBS-off  vs.  RVS
# Non-significant, p:  0.2637566758374802
# DBS-off  mean is:  0.264  SEM is:  2.331  Median is:  -0.458
# RVS  mean is:  -6.959  SEM is:  4.315  Median is:  -3.006
#
# All-on  vs.  RVS
# Non-significant, p:  0.8968329365171278
# All-on  mean is:  -6.15  SEM is:  4.389  Median is:  -9.678
# RVS  mean is:  -6.959  SEM is:  4.315  Median is:  -3.006
#
# DBS-off mean:  0.264
# DBS-off median:  -0.458
# DBS-off st. dev.:  11.419
# DBS-off SEM:  2.331
#
# All-on mean:  -6.15
# All-on median:  -9.678
# All-on st. dev.:  29.445
# All-on SEM:  4.389
#
# RVS mean:  -6.959
# RVS median:  -3.006
# RVS st. dev.:  29.898
# RVS SEM:  4.315
# DBS-off  vs.  All-on
# Non-significant, p:  0.32903125732469096
# DBS-off  mean is:  111.486  SEM is:  13.454  Median is:  86.112
# All-on  mean is:  87.192  SEM is:  16.269  Median is:  68.686
#
# DBS-off  vs.  RVS
# Non-significant, p:  0.05356120756498658
# DBS-off  mean is:  111.486  SEM is:  13.454  Median is:  86.112
# RVS  mean is:  77.605  SEM is:  9.974  Median is:  68.637
#
# All-on  vs.  RVS
# Non-significant, p:  0.6156045593125017
# All-on  mean is:  87.192  SEM is:  16.269  Median is:  68.686
# RVS  mean is:  77.605  SEM is:  9.974  Median is:  68.637
#
# DBS-off mean:  111.486
# DBS-off median:  86.112
# DBS-off st. dev.:  65.909
# DBS-off SEM:  13.454
#
# All-on mean:  87.192
# All-on median:  68.686
# All-on st. dev.:  109.136
# All-on SEM:  16.269
#
# RVS mean:  77.605
# RVS median:  68.637
# RVS st. dev.:  69.103
# RVS SEM:  9.974
# 0

# %%
p1 = 13
p2 = 30

data = copy.deepcopy(df_all)
baseValues, zz, zz, zz, zz, zz = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

data = data[(data["TreatmentOrder"] == "dbs_off,rvs,all_on")]
zz, zz, allValues2, allMeans2, rvsValues1, rvsMeans1 = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

data = data[(data["TreatmentOrder"] == "dbs_off,all_on,rvs")]
zz, zz, allValues1, allMeans1, rvsValues2, rvsMeans2 = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= False)

ones = customUnravel([allValues1, rvsValues1])
twos = customUnravel([allValues2, rvsValues2])
print(ones)
custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( ones, 2, scatter = True, sds = True, w = [.5], color = 'k')

custombox( twos, 3, scatter = True, sds = True, w = [.5], color = 'k')
plt.ylim([-75,100])
plt.xticks([1,2,3],labels = ["DBS-off","1st","2nd"])
exportFigure("Mean_13_30_order_Fig2G")
plt.show()

printTtest(baseValues,ones,"DBS-off","1st")
printTtest(baseValues,twos,"DBS-off","2nd")
printTtest(ones,twos,"1st","2nd")
statout(baseValues,ones,twos)

p1 = 13
p2 = 30

data = copy.deepcopy(df_all)
baseValues, zz, zz, zz, zz, zz = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

data = data[(data["TreatmentOrder"] == "dbs_off,rvs,all_on")]
zz, zz, allValues2, allMeans2, rvsValues1, rvsMeans1 = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

data = data[(data["TreatmentOrder"] == "dbs_off,all_on,rvs")]
zz, zz, allValues1, allMeans1, rvsValues2, rvsMeans2 = gen_allSession_Data(data, p1 = p1, p2 = p2, baseCut = -3, testCut = -6, toMax= True)

ones = customUnravel([allValues1, rvsValues1])
twos = customUnravel([allValues2, rvsValues2])
print(ones)
custombox( baseValues,1, scatter = True, sds = True, w = [.5])

custombox( ones, 2, scatter = True, sds = True, w = [.5], color = 'k')

custombox( twos, 3, scatter = True, sds = True, w = [.5], color = 'k')

plt.xticks([1,2,3],labels = ["DBS-off","1st","2nd"])
exportFigure("Max_13_30_order_Fig2G_extra")
plt.show()

printTtest(baseValues,ones,"DBS-off","1st")
printTtest(baseValues,twos,"DBS-off","2nd")
printTtest(ones,twos,"1st","2nd")
statout(baseValues,ones,twos)
# Out:
# [  8.79914421  -7.13730723  -2.01395595   7.34365778  20.85850219
#   24.60394045  -0.3053159   -4.93452121 -11.24583707  -6.89072366
#    5.99402666  20.1554224   20.01776952  11.52252372  12.33622514
#   14.13423167   9.98749268  33.64935551 -16.46427995  -0.70809682
#   -9.18624036 -20.41974326 -19.86186902  -8.97121381  -4.46564256
#    1.45629718   9.43623249   5.88628612   4.04701687   2.22816003
#   11.83435839   5.49568593  10.22634454  12.7817825    2.83833791
#    1.76632165 -17.8947225  -27.59029227 -22.80150706 -14.28567614
#  -37.14856496 -28.18420014 -24.90133437 -38.58809911 -26.99278232
#  -16.79661765 -41.52100791 -34.93102702  46.9956428   10.55198749
#   -8.85742041 -14.97867997  -0.6273778    0.39802837  38.2781596
#   -1.88564633  -2.98612391   4.68621141  13.20525296  -5.72187192]
# DBS-off  vs.  1st
# Non-significant, p:  0.3253889071665903
# DBS-off  mean is:  0.99  SEM is:  1.505  Median is:  1.568
# 1st  mean is:  -1.796  SEM is:  2.359  Median is:  -0.466
#
# DBS-off  vs.  2nd
# Significant, p:  0.017471343458965654
# DBS-off  mean is:  0.99  SEM is:  1.505  Median is:  1.568
# 2nd  mean is:  -6.907  SEM is:  2.984  Median is:  -11.046
#
# 1st  vs.  2nd
# Non-significant, p:  0.18145181110825603
# 1st  mean is:  -1.796  SEM is:  2.359  Median is:  -0.466
# 2nd  mean is:  -6.907  SEM is:  2.984  Median is:  -11.046
#
# DBS-off mean:  0.99
# DBS-off median:  1.568
# DBS-off st. dev.:  11.66
# DBS-off SEM:  1.505
#
# All-on mean:  -1.796
# All-on median:  -0.466
# All-on st. dev.:  18.271
# All-on SEM:  2.359
#
# RVS mean:  -6.907
# RVS median:  -11.046
# RVS st. dev.:  21.925
# RVS SEM:  2.984
#
# [149.1273837   93.41584802 168.8113415  201.45106999 187.59673982
#  251.77623277 116.91428287  93.39099555  71.75099445 115.37675067
#  150.45648196 127.29979193 162.34411295 160.11640987 141.24398397
#  175.5624212  158.22454843 200.12898367  49.57688599  99.67481272
#   55.59002781  45.89514969  47.3163397   99.96301401 145.4532127
#  150.25979799 190.96021077 129.79844074 116.73266493 147.22479461
#   99.999953    85.78599671  85.33659789  79.19054023  66.81500833
#   83.30308867 107.14562903  73.41400859  61.87386554 135.17179604
#  128.1526079  138.63767167   2.0082566    3.22415927   9.29201736
#   31.59190825  10.64764102   5.75849674 194.46521021  52.57241491
#   62.00825381  32.10783902  25.10083279  52.95710699 116.44093292
#   97.50213157  37.4908535   70.45924086  62.92316726  42.72121438]
# DBS-off  vs.  1st
# Non-significant, p:  0.19872881582685864
# DBS-off  mean is:  116.841  SEM is:  9.654  Median is:  98.25
# 1st  mean is:  100.959  SEM is:  7.436  Median is:  98.588
#
# DBS-off  vs.  2nd
# Non-significant, p:  0.08460351023998865
# DBS-off  mean is:  116.841  SEM is:  9.654  Median is:  98.25
# 2nd  mean is:  93.687  SEM is:  8.845  Median is:  73.786
#
# 1st  vs.  2nd
# Non-significant, p:  0.5314853245054088
# 1st  mean is:  100.959  SEM is:  7.436  Median is:  98.588
# 2nd  mean is:  93.687  SEM is:  8.845  Median is:  73.786
#
# DBS-off mean:  116.841
# DBS-off median:  98.25
# DBS-off st. dev.:  74.777
# DBS-off SEM:  9.654
#
# All-on mean:  100.959
# All-on median:  98.588
# All-on st. dev.:  57.6
# All-on SEM:  7.436
#
# RVS mean:  93.687
# RVS median:  73.786
# RVS st. dev.:  64.999
# RVS SEM:  8.845
# 0
